# %%
import random
def play_game():
  user=input("Enter a choice (rock,paper,scissors):").lower()
  while user not in ['rock','paper','scissors']:
    user=input("Invalid input. Please enterrock,paper,or scissors:").lower()
  computer=random.choice(['rock','paper','scissors'])
  print(f"\nYou chose: {user}")
  print(f"Computer chose: {computer}\n")

  if user== computer:
    return "It's a tie!"
  elif (user=='rock' and computer=='scissors') or\
       (user=='paper' and computer=='rock') or \
       (user=='scissors' and computer=='paper'):
    return "You Win!"
  else:
    return "You lose!"
print("Welcome to Rock=Paper-Scissors!")
while True:
  print(play_game())
  again=input("Play again? (Yes/No):").lower()
  if again !='yes':
    break
# Out:
# Welcome to Rock=Paper-Scissors!
# Enter a choice (rock,paper,scissors):paper
#
# You chose: paper
# Computer chose: rock
#
# You Win!
# Play again? (Yes/No):yes
# Enter a choice (rock,paper,scissors):scissor
# Invalid input. Please enterrock,paper,or scissors:scissors
#
# You chose: scissors
# Computer chose: scissors
#
# It's a tie!
# Play again? (Yes/No):no

# %%
import math
def perimeter(radius):
  return 2*math.pi*radius
rad=float(input("Enter the radius of the circle:"))
print("the perimeter of circle =",perimeter(rad))
# Out:
# Enter the radius of the circle:122
# the perimeter of circle = 766.5486074759095

# %%
p=float(input("Enter the amount:"))
t=float(input("Enter the time in year:"))
r=float(input("Enter the rate:"))
SI=(p*t*r)/100
print("The simple interest is=:",SI)
# Out:
# Enter the amount:21
# Enter the time in year:2
# Enter the rate:3
# The simple interest is=: 1.26

# %%
def si(principal,rate,time):
    return (principal*+rate*time)/100

principal=float(input("\nEnter the amount:"))
rate=float(input("Enter the rate:"))
time=float(input("Enter the time:"))
interest=si(principal,rate,time)
print("Simple Interest=:",interest)
# Out:
# Enter the amount:12000
# Enter the rate:12
# Enter the time:1
# Simple Interest=: 1440.0
