# %%
import pandas as pd
import statistics
df=pd.read_csv("/content/marksheet.csv")
df.head()
#display(df)
# Out:
#    id     Name  Gender  Age Section  Science  English  History  Maths  Total
# 0   1  Bronnie  Female   13       C       21       81       62     49    213
# 1   2   Lemmie    Male   15       B       29       41       17     40    127
# 2   3    Danya  Female   14       C       12       87       16     96    211
# 3   4    Denna  Female   14       B       15       53       82     33    183
# 4   5  Jocelin    Male   14       A       43        6        3     21     73

# %%
col=df['Science'].to_numpy()
print(col)
# Out:
# [ 21  29  12  15  43  98  38  25  39  35 100  19  65  93  98  53  91   5
#   62  41  76   3   5  48  17  16  93  60  19  95  14  17  17  54   5  93
#   54  90  71 100  10  21  43  26  65  50  84  78  81  94  31  17  15  23
#   55  53  46  64  41  61  16  49  16  78  88  85  45  39  84  34  95  48
#   72  46  85  32  27  87  27  13   1  84  59  34  36  17   8  44  58  64
#   23  79  22  43  64  58  19  40  72  66  64  80   2  37  68  62  57  56
#   11  82   2  23  22  41  23  80  63  90   2  80  79   4  18  70  68  29
#   76   3  28  23  85  13  19  77  96   5  52  10  52  21  52  77   5  63
#   76  43  33  92  51  53  92  26  23  47  32  55  67  72  73  61  58 100
#   44  91  35  67  84  23  95  38  34  86  55  94  63  95  92  87  95  32
#   98  62  60  53  75  48  27  60  87  14  38  39  50  48  13  92  82  98
#   30  57  84  89  45  84   7  54  49  56  59   7  28  85  63  87  68   5
#   71  72  58  81   6  60  92 100  84  16  22  78   4  15  50  81  65  91
# ...

# %%
import numpy as np
mean=np.mean(col)
median=np.median(col)
#mode=np.mode(col)
print(mean)
print(median)
#print(mode)
# Out:
# 51.44
# 53.0

# %%
mean=df['Science'].mean()
median=df['Science'].median()
mode=df['Science'].mode()
print('mean=',mean)
print('median=',median)
print('mode=',mode)
# Out:
# mean= 51.44
# median= 53.0
# mode= 0    23
# 1    84
# Name: Science, dtype: int64

# %%
mean=df['Science'].mean()
median=df['Science'].median()
mode=df['Science'].mode()
print('mean=',mean)
print('median=',median)
print('mode=',mode)
# Out:
# mean= 51.44
# median= 53.0
# mode= 0    23
# 1    84
# Name: Science, dtype: int64

# %%
import pandas as pd
df=pd.read_csv("/content/marksheet.csv")
data1=df['Science'].to_numpy()
#print(data1)

# %%
mean=np.mean(data1)
median=np.median(data1)
mode=statistics.mode(data1)
print('mean=',mean)
print('median=',median)
print('mode=',mode)
# Out:
# mean= 51.44
# median= 53.0
# mode= 84

# %%
data2=df['English'].to_numpy()
#print(data2)
mean=np.mean(data2)
median=np.median(data2)
mode=statistics.mode(data2)
print('mean=',mean)
print('median=',median)
print('mode=',mode)
# Out:
# mean= 47.98
# median= 47.5
# mode= 4

# %%
data3=df['History'].to_numpy()
#print(data3)
mean=np.mean(data3)
median=np.median(data3)
mode=statistics.mode(data3)
print('mean=',mean)
print('median=',median)
print('mode=',mode)
# Out:
# mean= 52.272
# median= 53.0
# mode= 83

# %%
data4=df['Maths'].to_numpy()
#print(data4)
mean=np.mean(data4)
median=np.median(data4)
mode=statistics.mode(data4)
print('mean=',mean)
print('median=',median)
print('mode=',mode)
# Out:
# mean= 53.016
# median= 52.5
# mode= 64

# %%
data5=df['Total'].to_numpy()
#print(data5)
mean=np.mean(data5)
median=np.median(data5)
mode=statistics.mode(data5)
print('mean=',mean)
print('median=',median)
print('mode=',mode)
# Out:
# mean= 204.708
# median= 203.5
# mode= 211
