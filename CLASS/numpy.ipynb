# %%
import numpy as np
num1=np.array([1,2,3,45,3])
print(num1)
# Out:
# [ 1  2  3 45  3]

# %%
num2=np.array([1,2,4,6,4,5,4,5,6,7,8,7,7,6,5,4,3,3])
print(num2)
print(num2.max())
print(num1.max())
print(num2.min())
print(num1.min())
print(num2.sum())
print(num1.sum())
# Out:
# [1 2 4 6 4 5 4 5 6 7 8 7 7 6 5 4 3 3]
# 8
# 45
# 1
# 1
# 87
# 54
