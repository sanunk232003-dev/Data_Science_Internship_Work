# %%
display(df.head())
# Out:
#   Employee ID        Full Name       Department          Job Title  Hire Date  \
# 0     EMP-101    Sarah Jenkins        Marketing     Senior Manager 2021-03-15
# 1     EMP-102     Michael Chen      Engineering  Software Engineer 2022-01-10
# 2     EMP-103  Elena Rodriguez  Human Resources      HR Specialist 2020-11-05
# 3     EMP-104      David Smith            Sales  Account Executive 2023-06-22
# 4     EMP-105     Priya Sharma          Product   Product Designer 2022-08-14
#
#    Salary (USD)
# 0         85000
# 1         92000
# 2         64000
# 3         55000
# 4         78000

# %%
department_counts = df['Department'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(department_counts, labels=department_counts.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
plt.title('Distribution of Employees by Department')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
job_title_counts = df['Job Title'].value_counts()
plt.figure(figsize=(12, 7))
sns.barplot(x=job_title_counts.index, y=job_title_counts.values, palette='plasma', hue=job_title_counts.index, legend=False)
plt.title('Employee Count by Job Title')
plt.xlabel('Job Title')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
