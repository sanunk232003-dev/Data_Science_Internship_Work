# %%
# !pip install pandas numpy scikit-learn matplotlib
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
data=pd.read_csv("/content/ml.csv")
data.head()
# Out:
#    Hours_studied  Attendance  Assignment  final_score
# 0              2          60           1           45
# 1              3          65           2           50
# 2              4          70           2           55
# 3              5          75           3           60
# 4              6          80           3           65

# %%
x=data[['Hours_studied','Attendance','Assignment']]
y=data['final_score']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictions=model.predict(x_test)
print(predictions)
# Out:
# [61.65782996 72.87634918]

# %%
print("Actual values",list(y_test))
print("Predicted values",predictions)
# Out:
# Actual values [60, 70]
# Predicted values [61.65782996 72.87634918]

# %%
import matplotlib.pyplot as plt
plt.scatter(data['Hours_studied'],data['final_score'])
plt.xlabel('Hours_studied')
plt.ylabel('final_score')
plt.show()

# %%
plt.bar(data['Hours_studied'],data['final_score'])
plt.xlabel('Hours_studied')
plt.ylabel('final_score')
plt.title("Bar:Hour vs Score")
plt.show()

# %%
import pandas as pd
data=pd.read_csv("/content/Salary_dataset (1).csv")
data.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
x=data['YearsExperience']
y=data['Salary']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train.values.reshape(-1, 1), y_train)
# Out:
# LinearRegression()

# %%
predictions=model.predict(x_test.values.reshape(-1, 1))
print(predictions)
# Out:
# [ 47934.37948063  92378.56327958  64260.81434555  46120.3311623
#  102355.82903037  72424.03177801]

# %%
print("Actual values",list(y_test))
print("Predicted values",predictions)
# Out:
# Actual values [39892.0, 98274.0, 56958.0, 43526.0, 113813.0, 67939.0]
# Predicted values [ 47934.37948063  92378.56327958  64260.81434555  46120.3311623
#  102355.82903037  72424.03177801]

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
model_dt=DecisionTreeRegressor()
model_dt.fit(x_train.values.reshape(-1, 1),y_train)
pred_dt=model_dt.predict(x_test.values.reshape(-1, 1))
print("DecisionTree Predictions",pred_dt)
print("Decision Tree MAE:",mean_absolute_error(y_test,pred_dt))
# Out:
# DecisionTree Predictions [ 37732.  91739.  55795.  37732. 101303.  66030.]
# Decision Tree MAE: 5011.833333333333

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
model_rf=RandomForestRegressor()
model_rf.fit(x_train.values.reshape(-1, 1),y_train)
pred_rf=model_rf.predict(x_test.values.reshape(-1, 1))
print("Random Forest Predictions",pred_rf)
print("Random Forest MAE:",mean_absolute_error(y_test,pred_rf))
# Out:
# Random Forest Predictions [ 44833.65  94782.6   57603.5   41411.18 103584.    65986.26]
# Random Forest MAE: 3895.851666666667

# %%
from sklearn.svm import SVR
model_svr=SVR()
model_svr.fit(x_train.values.reshape(-1, 1),y_train)
pred_svr=model_svr.predict(x_test.values.reshape(-1, 1))
print("SVR Predictions",pred_svr)
print("SVR MAE:",mean_absolute_error(y_test,pred_svr))
# Out:
# SVR Predictions [65234.41519127 65248.48253964 65236.80180221 65234.58722436
#  65250.27590816 65240.30463443]
# SVR MAE: 23269.456855933055

# %%
from sklearn.neighbors import KNeighborsRegressor
model_knn=KNeighborsRegressor(n_neighbors=3)
model_knn.fit(x_train.values.reshape(-1, 1),y_train)
pred_knn=model_knn.predict(x_test.values.reshape(-1, 1))
print("KNN Predictions",pred_knn)
print("KNN MAE:",mean_absolute_error(y_test,pred_knn))
# Out:
# KNN Predictions [ 51508.66666667  95661.          58698.66666667  41094.
#  105439.33333333  70077.        ]
# KNN MAE: 4819.0

# %%
print("Linear Regression Error",mean_absolute_error(y_test,predictions))
print("Decision Tree Error",mean_absolute_error(y_test,pred_dt))
print("Random Forest Error",mean_absolute_error(y_test,pred_rf))
print("SVR Error",mean_absolute_error(y_test,pred_svr))
print("KNN Error",mean_absolute_error(y_test,pred_knn))
# Out:
# Linear Regression Error 6629.527409424082
# Decision Tree Error 5011.833333333333
# Random Forest Error 3895.851666666667
# SVR Error 23269.456855933055
# KNN Error 4819.0

# %%
import matplotlib.pyplot as plt
plt.scatter(data['YearsExperience'],data['Salary'])
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.show()

# %%
plt.bar(data['YearsExperience'],data['Salary'])
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title("Bar:YearsExperience vs Salary")
plt.show()

# %%
import pandas as pd
data=pd.read_csv("/content/faculty_dataset.csv")
data.head()
display(data)
# Out:
#       Age  Teaching_Experience  Industry_Experience  Workshops_Attended  \
# 0      63                   19                    9                   6
# 1      53                   26                    8                  16
# 2      39                    2                    6                   0
# 3      32                    3                    9                   4
# 4      45                    6                    1                   5
# ...   ...                  ...                  ...                 ...
# 1995   64                   12                    8                   7
# 1996   61                   20                    6                  14
# 1997   57                    5                   10                   1
# 1998   60                    3                    0                   0
# 1999   27                    9                   11                   8
#
#       Training_Hours  Team_Project_Count  Student_Feedback  Online_Courses
# 0                 72                  15                82              15
# 1                 30                  13                72              15
# 2                 14                  14                61               2
# 3                134                  19                60               8
# 4                172                  12                62               7
# ...              ...                 ...               ...             ...
# 1995              96                   9                82               3
# 1996              82                   1                55              17
# 1997             184                  10                85               3
# 1998             113                  10                62               5
# 1999             167                  10                96              13
#
# [2000 rows x 8 columns]

# %%
x=data[['Age','Teaching_Experience','Training_Hours']]
y=data['Student_Feedback']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictions=model.predict(x_test)
print(predictions)
# Out:
# [74.68229005 74.43710471 75.29157627 74.92706    74.87313082 74.96464723
#  73.57595454 73.64154338 74.08207692 73.69807361 75.05163924 74.16447156
#  74.46622836 73.10078452 75.18215148 74.51232291 74.04690613 75.13571447
#  74.37961278 75.1834119  75.26741917 75.00313546 75.63868451 75.47610762
#  74.72940699 75.46519358 75.4674157  73.37541398 76.79425715 76.70638115
#  75.58174386 75.53155225 74.67291324 75.51903533 75.66854402 75.62076638
#  74.74074367 75.38577392 75.05925281 74.78128166 74.42100807 74.68866017
#  74.31312295 75.64145066 73.15679745 75.35958406 73.8875835  74.80322637
#  74.90062483 75.36770769 74.49347709 75.02873034 75.99539535 74.88316083
