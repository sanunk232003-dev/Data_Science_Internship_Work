# %%
Print("Hello Machine Learning")
# Out:
# Hello Machine Learning

# %%
# !pip install pandas numpy scikit-learn matplotlib
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
data=pd.read_csv("/content/ml2.csv")
data.head()
# Out:
#    Hours_Studied  Attendance  Assignment  Final_score
# 0              1          45          12           40
# 1              2          45          13           45
# 2              3          45          14           50
# 3              4          45          15           55
# 4              4          45          16           60

# %%
x=data[['Hours_Studied','Attendance','Assignment']]
y=data['Final_score']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictions=model.predict(x_test)
print(predictions)
# Out:
# [45.]

# %%
print("Actual values",list(y_test))
print("Predicted values",predictions)
# Out:
# Actual values [45]
# Predicted values [45.]

# %%
import matplotlib.pyplot as plt
plt.scatter(data['Hours_Studied'],data['Final_score'])
plt.xlabel('Hours_studied')
plt.ylabel('final_score')
plt.show()

# %%
plt.bar(data['Hours_Studied'],data['Final_score'])
plt.xlabel('Hours_studied')
plt.ylabel('final_score')
plt.title("Bar:Hour vs Score")
plt.show()

# %%
import pandas as pd
data=pd.read_csv("/content/ml.csv")   #/content/ml2.csv
data.head()
display(data)
# Out:
#    Maths  Kannada  \tEnglish\t  ComputerScience  \tTotal_score
# 0     23       45           23               50            141
# 1     45       43           27               44            159
# 2     33       41           45               40            159
# 3     48       33           33               46            160
# 4     15       39           39               41            134

# %%
x=data[['Maths','Kannada','\tEnglish\t','ComputerScience']]
y=data['\tTotal_score']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictions=model.predict(x_test)
print(predictions)
# Out:
# [159.38047137]

# %%
print("Actual values",list(y_test))
print("Predicted values",predictions)
# Out:
# Actual values [160]
# Predicted values [159.38047137]

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
model_dt=DecisionTreeRegressor()
model_dt.fit(x_train,y_train)
pred_dt=model_dt.predict(x_test)
print("DecisionTree Predictions",pred_dt)
print("Decision Tree MAE:",mean_absolute_error(y_test,pred_dt))
# Out:
# DecisionTree Predictions [159.]
# Decision Tree MAE: 1.0

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
model_rf=RandomForestRegressor()
model_rf.fit(x_train,y_train)
pred_rf=model_rf.predict(x_test)
print("Random Forest Predictions",pred_rf)
print("Random Forest MAE:",mean_absolute_error(y_test,pred_rf))
# Out:
# Random Forest Predictions [152.59]
# Random Forest MAE: 7.409999999999997

# %%
from sklearn.svm import SVR
model_svr=SVR()
model_svr.fit(x_train,y_train)
pred_svr=model_svr.predict(x_test)
print("SVR Predictions",pred_svr)
print("SVR MAE:",mean_absolute_error(y_test,pred_svr))
# Out:
# SVR Predictions [150.79122768]
# SVR MAE: 9.208772316397983

# %%
from sklearn.neighbors import KNeighborsRegressor
model_knn=KNeighborsRegressor(n_neighbors=3)
model_knn.fit(x_train,y_train)
pred_knn=model_knn.predict(x_test)
print("KNN Predictions",pred_knn)
print("KNN MAE:",mean_absolute_error(y_test,pred_knn))
# Out:
# KNN Predictions [153.]
# KNN MAE: 7.0

# %%
print("Linear Regression Error",mean_absolute_error(y_test,predictions))
print("Decision Tree Error",mean_absolute_error(y_test,pred_dt))
print("Random Forest Error",mean_absolute_error(y_test,pred_rf))
print("SVR Error",mean_absolute_error(y_test,pred_svr))
print("KNN Error",mean_absolute_error(y_test,pred_knn))
# Out:
# Linear Regression Error 0.6195286261686874
# Decision Tree Error 1.0
# Random Forest Error 7.409999999999997
# SVR Error 9.208772316397983
# KNN Error 7.0

# %%
import pandas as pd
data=pd.read_csv("/content/Salary_dataset (1).csv")
data.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
x=data['YearsExperience']
y=data['Salary']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train.values.reshape(-1, 1), y_train)
# Out:
# LinearRegression()

# %%
predictions=model.predict(x_test.values.reshape(-1, 1))
print(predictions)
# Out:
# [ 46487.11526561  80986.62566681  55811.30726594  39960.18086539
#   81919.04486684 114553.71686797]

# %%
print("Actual values",list(y_test))
print("Predicted values",predictions)
# Out:
# Actual values [39892.0, 81364.0, 64446.0, 37732.0, 93941.0, 116970.0]
# Predicted values [ 46487.11526561  80986.62566681  55811.30726594  39960.18086539
#   81919.04486684 114553.71686797]

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
model_dt=DecisionTreeRegressor()
model_dt.fit(x_train.values.reshape(-1, 1),y_train)
pred_dt=model_dt.predict(x_test.values.reshape(-1, 1))
print("DecisionTree Predictions",pred_dt)
print("Decision Tree MAE:",mean_absolute_error(y_test,pred_dt))
# Out:
# DecisionTree Predictions [ 43526.  83089.  54446.  46206.  83089. 112636.]
# Decision Tree MAE: 6503.166666666667

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
model_rf=RandomForestRegressor()
model_rf.fit(x_train.values.reshape(-1, 1),y_train)
pred_rf=model_rf.predict(x_test.values.reshape(-1, 1))
print("Random Forest Predictions",pred_rf)
print("Random Forest MAE:",mean_absolute_error(y_test,pred_rf))
# Out:
# Random Forest Predictions [ 48846.29  79629.07  56257.66  44346.98  83999.6  112302.45]
# Random Forest MAE: 6683.581666666665

# %%
from sklearn.svm import SVR
model_svr=SVR()
model_svr.fit(x_train.values.reshape(-1, 1),y_train)
pred_svr=model_svr.predict(x_test.values.reshape(-1, 1))
print("SVR Predictions",pred_svr)
print("SVR MAE:",mean_absolute_error(y_test,pred_svr))
# Out:
# SVR Predictions [64620.64429184 64630.29782133 64620.74759085 64621.69099007
#  64630.71368525 64636.03667209]
# SVR MAE: 25028.50578234716

# %%
from sklearn.neighbors import KNeighborsRegressor
model_knn=KNeighborsRegressor(n_neighbors=3)
model_knn.fit(x_train.values.reshape(-1, 1),y_train)
pred_knn=model_knn.predict(x_test.values.reshape(-1, 1))
print("KNN Predictions",pred_knn)
print("KNN MAE:",mean_absolute_error(y_test,pred_knn))
# Out:
# KNN Predictions [ 53440.          80286.          57080.          43025.33333333
#   80286.         113537.        ]
# KNN MAE: 7395.555555555556

# %%
print("Linear Regression Error",mean_absolute_error(y_test,predictions))
print("Decision Tree Error",mean_absolute_error(y_test,pred_dt))
print("Random Forest Error",mean_absolute_error(y_test,pred_rf))
print("SVR Error",mean_absolute_error(y_test,pred_svr))
print("KNN Error",mean_absolute_error(y_test,pred_knn))
# Out:
# Linear Regression Error 5378.9335772414115
# Decision Tree Error 6503.166666666667
# Random Forest Error 6683.581666666665
# SVR Error 25028.50578234716
# KNN Error 7395.555555555556

# %%
import matplotlib.pyplot as plt
plt.scatter(data['YearsExperience'],data['Salary'])
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.show()

# %%
plt.bar(data['YearsExperience'],data['Salary'])
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title("Bar:YearsExperience vs Salary")
plt.show()

# %%
import pandas as pd
data=pd.read_csv("/content/fmcg_sales_marketing_profitability_2023_2025.csv")
data.head()
# Out:
#    Units_Sold  Unit_Price_USD  Gross_Sales_USD  COGS_USD  Profit_USD  \
# 0          73            8.47           618.31    314.09      139.86
# 1          99            2.89           286.11    123.79       74.96
# 2         361            5.96          2151.56   1011.60      531.86
# 3         603            3.80          2291.40   1133.66      541.70
# 4         113            3.18           359.34    157.70       99.03
#
#    Profit_Margin_Pct
# 0              24.84
# 1              29.07
# 2              29.19
# 3              28.83
# 4              31.48

# %%
x=data[['Units_Sold','Unit_Price_USD','Unit_Price_USD']]
y=data['Profit_USD']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictions