# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/data (1).csv')
df.plot()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/data (1).csv')
df.plot(kind='scatter',x='Duration',y='Calories')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/data (1).csv')
x_scatter=df['Duration']
y_scatter=df['Calories']
plt.scatter(x_scatter,y_scatter,color='red',marker='*',label='Scatter Plot')
plt.title('Customizes Line and Scatter plots')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/data (1).csv')
x_scatter=df['Duration']
y_scatter=df['Calories']
plt.scatter(x_scatter,y_scatter,color='red',marker='*',label='Scatter Plot')
plt.title('Customizes Line and Scatter plots')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/data (1).csv')
x_line=df['Duration']
y_line=df['Calories']
plt.plot(x_line,y_line,linestyle='-',color='black',label='Line Plot')
plt.title('Customized Line and Scatter plots')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x_line=np.array([1,2,3,4,5])
y_line=np.array([10,20,30,40,50])
plt.plot(x_line,y_line,linestyle='-.',color='black',label='Line Plot')
plt.title('Customized Line and Scatter plots')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt
x_line=np.array([1,2,3,4,5,])
y_line=np.array([10,20,30,40,50])
plt.plot(x_line,y_line,linestyle='',marker='*',color='red',label='Scatter Plot')
plt.title('Customized Line and Scatter Plots')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv('/content/data (1).csv')
print(data)
# Out:
#      Duration  Pulse  Maxpulse  Calories      Date
# 0          60    110       130     409.1   13/8/90
# 1          60    117       145     479.0  23/11/90
# 2          60    103       135     340.0  23/11/91
# 3          45    109       175     282.4  23/11/92
# 4          45    117       148     406.0  23/11/93
# ..        ...    ...       ...       ...       ...
# 164        60    105       140     290.8       NaN
# 165        60    110       145     300.0       NaN
# 166        60    115       145     310.2       NaN
# 167        75    120       150     320.4       NaN
# 168        75    125       150     330.4       NaN
#
# [169 rows x 5 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv('/content/dataset.txt')
plt.plot(data['Duration'],data['Calories'])
plt.xlabel('Duration')
plt.ylabel('Calories')
plt.title('Duration and Calories')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv('/content/dataset.txt')
plt.plot(data['Duration'],data['Calories'])
plt.xlabel('Duration')
plt.ylabel('Calories')
plt.title('Duration and Calories')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1222697202.py in <cell line: 0>()
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 3 data=pd.read_csv('/content/dataset.txt')
#       4 plt.plot(data['Duration'],data['Calories'])
#       5 plt.xlabel('Duration')
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv('/content/data (1).csv')
avg_cal = df.groupby("Duration")["Calories"].mean()
plt.bar(avg_cal.index, avg_cal.values)
plt.xlabel("Duration (minutes)")
plt.ylabel("Average Calories")
plt.title("Average Calories Burned for Each Duration")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv('/content/data (1).csv')
duration_count = df["Duration"].value_counts()
plt.pie(
duration_count.values,
labels=duration_count.index,
autopct="%1.1f%%"
)
plt.title("Workout Duration Distribution")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv('/content/data (1).csv')
plt.pie(
    data["Duration"],
    labels=data["Calories"],
    autopct="%1.1f%%"
)
plt.title("Workout Duration Distribution")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_excel('/content/student.xlsx')
plt.plot(data['class'],data['mark'])
plt.xlabel('class')
plt.ylabel('mark')
plt.title('Class and Marks')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/data (1).csv')
plt.scatter(df["Duration"],df["Pulse"],label="Pulse")
plt.scatter(df["Duration"],df["Maxpulse"],label="Max Pulse")
plt.xlabel("Duration(minutes)")
plt.ylabel("Pulse Rate")
plt.title("Pulse and Max Pulse vs Duration")
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/data (1).csv')
plt.plot(df["Duration"],df["Pulse"],label="Pulse")
plt.plot(df["Duration"],df["Maxpulse"],label="Max Pulse")
plt.xlabel("Duration(minutes)")
plt.ylabel("Pulse Rate")
plt.title("Pulse and Max Pulse vs Duration")
plt.legend()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('/content/data (1).csv')
sns.lineplot(x="Duration",y="Calories",data=df)
plt.title=("Calories vs Duration")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('/content/data (1).csv')
#print(df.to_string())
sns.scatterplot(x="Pulse",y="Calories",data=df)
plt.title("Pulse vs Calories")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('/content/data (1).csv')
sns.barplot(x="Duration",y="Calories",data=df)
plt.title("Average Calories by Duration")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('/content/data (1).csv')
print(df.to_string())
sns.boxplot(x="Duration",y="Calories",data=df)
plt.title("Average Calories by Duration")
plt.show()
# Out:
#     Duration  Pulse  Maxpulse  Calories        Date
# 0         60    110       130     409.1  13-08-1990
# 1         60    117       145     479.0  23-11-1990
# 2         60    103       135     340.0  23-11-1991
# 3         45    109       175     282.4  23-11-1992
# 4         45    117       148     406.0  23-11-1993
# 5         60    102       127     300.0  23-11-1994
# 6         60    110       136     374.0  23-11-1995
# 7         45    104       134     253.3  23-11-1996
# 8         30    109       133     195.1         NaN
# 9         60     98       124     269.0         NaN
# 10        60    103       147     329.3         NaN
# 11        60    100       120     250.7         NaN
# 12        60    106       128     345.3         NaN
# 13        60    104       132     379.3         NaN
# 14        60     98       123     275.0         NaN
# 15        60     98       120     215.2         NaN
# 16        60    100       120     300.0  05-05-1999
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('/content/data (1).csv')
print(df.to_string())
sns.histplot(x="Duration",y="Calories",data=df)
plt.title("Average Calories by Duration")
plt.show()
# Out:
#     Duration  Pulse  Maxpulse  Calories        Date
# 0         60    110       130     409.1  13-08-1990
# 1         60    117       145     479.0  23-11-1990
# 2         60    103       135     340.0  23-11-1991
# 3         45    109       175     282.4  23-11-1992
# 4         45    117       148     406.0  23-11-1993
# 5         60    102       127     300.0  23-11-1994
# 6         60    110       136     374.0  23-11-1995
# 7         45    104       134     253.3  23-11-1996
# 8         30    109       133     195.1         NaN
# 9         60     98       124     269.0         NaN
# 10        60    103       147     329.3         NaN
# 11        60    100       120     250.7         NaN
# 12        60    106       128     345.3         NaN
# 13        60    104       132     379.3         NaN
# 14        60     98       123     275.0         NaN
# 15        60     98       120     215.2         NaN
# 16        60    100       120     300.0  05-05-1999
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('/content/data (1).csv')
print(df.to_string())
corr = df[["Duration", "Pulse", "Maxpulse", "Calories"]].corr()
sns.heatmap(corr, annot=True)
plt.title("Correlation Heatmap")
plt.show()
# Out:
#     Duration  Pulse  Maxpulse  Calories        Date
# 0         60    110       130     409.1  13-08-1990
# 1         60    117       145     479.0  23-11-1990
# 2         60    103       135     340.0  23-11-1991
# 3         45    109       175     282.4  23-11-1992
# 4         45    117       148     406.0  23-11-1993
# 5         60    102       127     300.0  23-11-1994
# 6         60    110       136     374.0  23-11-1995
# 7         45    104       134     253.3  23-11-1996
# 8         30    109       133     195.1         NaN
# 9         60     98       124     269.0         NaN
# 10        60    103       147     329.3         NaN
# 11        60    100       120     250.7         NaN
# 12        60    106       128     345.3         NaN
# 13        60    104       132     379.3         NaN
# 14        60     98       123     275.0         NaN
# 15        60     98       120     215.2         NaN
# 16        60    100       120     300.0  05-05-1999
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('/content/data (1).csv')
sns.pairplot(df)
plt.title("Pairplot")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('/content/data (1).csv')
sns.barplot(x="Duration",y="Calories",data=df)
plt.title("Jointplot")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('/content/index_1 (1).csv')
sns.barplot(x="money",y="item",data=df)
plt.title("Average Money by Item")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('/content/stdmark.csv')
sns.barplot(x="Student_ID",y="Attendance",data=df)
plt.title("Average Mark by Class")
plt.show()

# %%
import pandas as pd
df=pd.read_csv('/content/stdmark.csv')
df['Average']=df[['Maths','Science','English']].mean(axis=1)
print(df)
# Out:
#    Student_ID   Name Gender  Maths  Science  English  Attendance    Average
# 0         101  Aarav      M     78       85       72          90  78.333333
# 1         102   Neha      F     88       91       84          95  87.666667
# 2         103  Rahul      M     65       70       60          75  65.000000
# 3         104  Priya      F     92       89       94          98  91.666667
# 4         105  Karan      M     55       60       58          68  57.666667

# %%
weak_students=df[df['Average']<60]
print(weak_students)
# Out:
#    Student_ID   Name Gender  Maths  Science  English  Attendance    Average
# 4         105  Karan      M     55       60       58          68  57.666667

# %%
df.groupby("Gender")['Average'].mean()
# Out:
# Gender
# F    89.666667
# M    67.000000
# Name: Average, dtype: float64

# %%
df[['Attendance','Average']].corr()
print(df)
df.plot(kind='bar',x='Attendance',y='Average')
plt.title('Attendance vs Average')
plt.xlabel('Attendance')
plt.ylabel('Average')
#df.show()
# Out:
#    Student_ID   Name Gender  Maths  Science  English  Attendance    Average
# 0         101  Aarav      M     78       85       72          90  78.333333
# 1         102   Neha      F     88       91       84          95  87.666667
# 2         103  Rahul      M     65       70       60          75  65.000000
# 3         104  Priya      F     92       89       94          98  91.666667
# 4         105  Karan      M     55       60       58          68  57.666667
# Text(0, 0.5, 'Average')

# %%
import pandas as pd
df=pd.read_csv('/content/sales.csv')
df['Revenue']=df['Quantity']*df['Price']
print(df)
# Out:
#    Order_Id     Product     Category  Quantity  Price Region  Revenue
# 0         1      Laptop  Electronics         2  55000  North   110000
# 1         2      Mobile  Electronics         5  20000  South   100000
# 2         3       Chair    Furniture         3   3000   West     9000
# 3         4       Table    Furniture         8   8000  North    64000
# 4         5  Headphones  Electronics         8   2500   East    20000

# %%
df.groupby('Category')['Revenue'].sum()
# Out:
# Category
# Electronics    230000
# Furniture       73000
# Name: Revenue, dtype: int64

# %%
df.groupby('Region')['Revenue'].sum()
# Out:
# Region
# East      20000
# North    174000
# South    100000
# West       9000
# Name: Revenue, dtype: int64

# %%
df.sort_values(by='Revenue',ascending=False).head(1)
# Out:
#    Order_Id Product     Category  Quantity  Price Region  Revenue
# 0         1  Laptop  Electronics         2  55000  North   110000

# %%
import numpy as np
temperature=np.array([
    [30,32,31,29,28],
    [35,36,34,33,32],
    [40,42,41,39,38]
])
daily_avg=temperature.mean(axis=1)
print(daily_avg)
# Out:
# [30. 34. 40.]

# %%
a=np.max(temperature)
print(a)
# Out:
# 42

# %%
b=np.argmax(daily_avg)+1
print(b)
# Out:
# 3

# %%
c=temperature[temperature>40]
print(c)
# Out:
# [42 41]

# %%
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_excel('/content/Coffee_sales (1) (1).xlsx')
df.plot(kind='hist',x='Weekdaysort',y='Monthsort')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_excel('/content/Coffee_sales (1) (1).xlsx')
df.plot(kind='bar',x='Weekdaysort',y='Monthsort')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/stdmark.csv')
df.plot(x='Student_ID',y='Maths')
plt.show()

# %%
import pandas as pd
df=pd.read_csv('/content/stdmark.csv')
df['Total']=df[['Maths','Science','English']].sum(axis=1)
print(df)
# Out:
#    Student_ID   Name Gender  Maths  Science  English  Attendance  Total
# 0         101  Aarav      M     78       85       72          90    235
# 1         102   Neha      F     88       91       84          95    263
# 2         103  Rahul      M     65       70       60          75    195
# 3         104  Priya      F     92       89       94          98    275
# 4         105  Karan      M     55       60       58          68    173

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/student-dataset.csv')
df.plot(kind='bar',x='english.grade',y='math.grade')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/student-dataset.csv')
df.plot(kind='scatter',x='english.grade',y='math.grade')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/student-dataset.csv')
df.plot(kind='hist',x='sciences.grade',y='portfolio.rating')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/student-dataset.csv')
df.plot(kind='line',x='coverletter.rating',y='refletter.rating')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/student-dataset.csv')
df.plot(kind='bar',x='coverletter.rating',y='portfolio.rating')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/student-dataset.csv')
df.plot(kind='scatter',x='coverletter.rating',y='portfolio.rating')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/student-dataset.csv')
df.plot(kind='hist',x='math.grade',y='portfolio.rating')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/student-dataset.csv')
df.plot(kind='line',x='math.grade',y='portfolio.rating')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/student-dataset.csv')
df.plot(kind='bar',x='math.grade',y='portfolio.rating')
plt.show()
